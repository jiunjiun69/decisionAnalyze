# %%
import configparser
import requests
from datetime import datetime
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('config.ini')
api_key =config.get('YouTube_API', 'api_key')
base_url = "https://www.googleapis.com/youtube/v3/"

# %%
def get_html_to_json(path):
    """組合 URL 後 GET 網頁並轉換成 JSON"""
    api_url = f"{base_url}{path}&key={api_key}"
    r = requests.get(api_url)
    if r.status_code == requests.codes.ok:
        data = r.json()
    else:
        data = None
    return data

# %%
def get_channel_uploads_id(channel_id, part='contentDetails'):
        """取得頻道上傳影片清單的ID"""
        path = f'channels?part={part}&id={channel_id}'
        data = get_html_to_json(path)
        try:
            uploads_id = data['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        except KeyError:
            uploads_id = None
        return uploads_id

# %% [markdown]
# # 數據來源為Jay Lee Painting的YouTube頻道

# %%
get_channel_uploads_id('UCHm9SiOLG8UoBT8STWY5mVA')
# Out:
# 'UUHm9SiOLG8UoBT8STWY5mVA'

# %%
def get_playlist(playlist_id, part='contentDetails', max_results=50):
        """取得影片清單ID中的影片"""
        path = f'playlistItems?part={part}&playlistId={playlist_id}&maxResults={max_results}'
        data = get_html_to_json(path)
        if not data:
            return []

        video_ids = []
        for data_item in data['items']:
            video_ids.append(data_item['contentDetails']['videoId'])
        return video_ids

# %%
len(get_playlist('UUHm9SiOLG8UoBT8STWY5mVA'))
# Out:
# 50

# %%
playlists = get_playlist('UUHm9SiOLG8UoBT8STWY5mVA')

# %%
def get_video(video_id, part='snippet,statistics'):
        """取得影片資訊"""
        path = f'videos?part={part}&id={video_id}'
        data = get_html_to_json(path)
        if not data:
            return {}
        # 以下整理並提取需要的資料
        data_item = data['items'][0]

        try:
            time_ = datetime.strptime(data_item['snippet']['publishedAt'], '%Y-%m-%dT%H:%M:%SZ')
        except ValueError:
            # 日期格式錯誤
            time_ = None

        url_ = f"https://www.youtube.com/watch?v={data_item['id']}"

        info = {
#             'id': data_item['id'],
#             'channelTitle': data_item['snippet']['channelTitle'],
#             'publishedAt': time_,
            'video_url': url_,
            'title': data_item['snippet']['title'],
#             'description': data_item['snippet']['description'],
            'likeCount': data_item['statistics']['likeCount'],
            'commentCount': data_item['statistics']['commentCount'],
            'viewCount': data_item['statistics']['viewCount']
        }
        return info

# %%
get_video('PqWH95EMmNM')
# Out:
# {'video_url': 'https://www.youtube.com/watch?v=PqWH95EMmNM',
#  'title': 'How to Draw a Couple Walking in the Rain / Red Acrylic Painting Techniques',
#  'likeCount': '2358',
#  'commentCount': '143',
#  'viewCount': '104866'}

# %%
video_url_array = []
title_array = []
likeCount_array = []
commentCount_array = []
viewCount_array = []

for playlist in playlists:
    video_data = get_video(playlist)
    
    video_url_array.append(video_data['video_url'])
    title_array.append(video_data['title'])
    likeCount_array.append(video_data['likeCount'])
    commentCount_array.append(video_data['commentCount'])
    viewCount_array.append(video_data['viewCount'])

# %%
df = pd.DataFrame()
df['video_url'] = video_url_array
df['title'] = title_array
df['likeCount'] = likeCount_array
df['commentCount'] = commentCount_array
# 46  Lavender Flower Forest / Easy Acrylic Painting...     55815         1187
# 47  Painting a Growing Tree from Sprout  / Acrylic...     16646          286
# 48  How to Draw a Girl Walking Dog  / Acrylic / Pa...     10579          323
# 49  Simple Watercolor Painting Technique / Drawing...      3063          141
#
#    viewCount
# 0     104866
# 1     228965
# 2      95156
# 3     760640
# 4    1115131
# 5    1751596
# 6     321694
# 7     103594
# 8    2644313
# 9     978930
# 10   7931171
# 11    792495
# 12   1344411
# 13    587823
# 14   3015791
# 15   8658572
# 16    144558
# 17   1992693
# 18  23458921
# 19   1020083
# 20    393046
# 21  10871296
# 22    291591
# 23   1013768
# 24  38686295
# 25    141032
# 26    235706
# 27    462539
# 28   3702385
# 29    684909
# 30   1163202
# 31    527179
# 32   1161003
# 33    656014
# 34    160571
# 35  10621945
# 36    311626
# 37   3630845
# 38    766379
# 39    203979
# 40    311024
# 41    961681
# 42   4248543
# 43  71603085
# 44    144440
# 45   5180793
# 46   6789063
# 47   2029454
# 48    443531
# 49    129247

# %%
max_likeCount = 0
for likeCount in df['likeCount']:
    if(float(max_likeCount) < float(likeCount)):
        max_likeCount = float(likeCount)
    else:
        pass
    
max_commentCount = 0
for commentCount in df['commentCount']:
    if(float(max_commentCount) < float(commentCount)):
        max_commentCount = float(commentCount)
    else:
        pass
    
max_viewCount = 0
for viewCount in df['viewCount']:
    if(float(max_viewCount) < float(viewCount)):
        max_viewCount = float(viewCount)
    else:
        pass

# %%
likeCount_score_array = []
for likeCount in df['likeCount']:
    likeCount_score_array.append(round(float(likeCount)/float(max_likeCount)*100, 2))
    
commentCount_score_array = []
for commentCount in df['commentCount']:
    commentCount_score_array.append(round(float(commentCount)/float(max_commentCount)*100, 2))
    
viewCount_score_array = []
for viewCount in df['viewCount']:
    viewCount_score_array.append(round(float(viewCount)/float(max_viewCount)*100, 2))
    
df['likeCount_score'] = likeCount_score_array
df['commentCount_score'] = commentCount_score_array
df['viewCount_score'] = viewCount_score_array
df
# Out:
#                                       video_url  \
# 0   https://www.youtube.com/watch?v=PqWH95EMmNM
# 1   https://www.youtube.com/watch?v=S14nS2KGUZI
# 2   https://www.youtube.com/watch?v=RjlajaLYvqk
# 3   https://www.youtube.com/watch?v=Gn3eE4jaKRA
# 4   https://www.youtube.com/watch?v=rd_SwWWKy7g
# 5   https://www.youtube.com/watch?v=M5eynslZhKU
# 6   https://www.youtube.com/watch?v=RC3p-MW7ZZM
# 7   https://www.youtube.com/watch?v=wlmd5812RjM
# 8   https://www.youtube.com/watch?v=GANrQfmSJcg
# 9   https://www.youtube.com/watch?v=SqNtzR-_muw
# 10  https://www.youtube.com/watch?v=9HDKoPEiFf4
# 11  https://www.youtube.com/watch?v=m6ICi_nNp58
# 12  https://www.youtube.com/watch?v=iadNUWMmxME
# 13  https://www.youtube.com/watch?v=Slq1yGl5OMk
# 14  https://www.youtube.com/watch?v=SHrqGcTlj9o
# 15  https://www.youtube.com/watch?v=cUhpq_dPU2M
# 29    684909             0.79                1.90             0.96
# 30   1163202             1.77                2.96             1.62
# 31    527179             1.16                2.37             0.74
# 32   1161003             1.71                2.80             1.62
# 33    656014             0.82                1.74             0.92
# 34    160571             0.47                1.13             0.22
# 35  10621945            13.15               18.51            14.83
# 36    311626             0.75                1.54             0.44
# 37   3630845             5.60                6.69             5.07
# 38    766379             1.22                1.71             1.07
# 39    203979             0.54                1.31             0.28
# 40    311024             0.82                1.60             0.43
# 41    961681             1.77                2.81             1.34
# 42   4248543             6.24                7.01             5.93
# 43  71603085           100.00              100.00           100.00
# 44    144440             0.45                0.86             0.20
# 45   5180793             5.76                7.52             7.24
# 46   6789063             5.95                7.96             9.48
# 47   2029454             1.77                1.92             2.83
# 48    443531             1.13                2.17             0.62
# 49    129247             0.33                0.95             0.18
#
#     final_score
# 0         0.595
# 1         0.724
# 2         0.457
# 3         1.724
# 4         1.903
# 5         2.140
# 6         1.117
# 7         1.025
# 8         3.577
# 9         2.121
# 10        8.131
# 11        1.750
# 12        2.328
# 13        2.278
# 14        2.973
# 15       13.973
# 16        0.775
# 17        3.169
# 18       24.140
# 19        2.156
# 20        0.957
# 21       11.056
# 22        0.926
# 23        1.962
# 24       37.773
# 25        0.594
# 26        0.715
# 27        1.081
# 28        6.633
# 29        1.362
# 30        2.350
# 31        1.723
# 32        2.246
# 33        1.290
# 34        0.775
# 35       15.998
# 36        1.114
# 37        6.092
# 38        1.450
# 39        0.899
# 40        1.171
# 41        2.247
# 42        6.594
# 43      100.000
# 44        0.630
# 45        6.788
# 46        7.308
# 47        1.951
# 48        1.599
# 49        0.625

# %%
max_final_score = 0
min_final_score = 100

for final_score in df['final_score']:
    if(float(max_final_score) < float(final_score)):
        max_final_score = float(final_score)
    else:
        pass
    
    if(float(min_final_score) > float(final_score)):
        min_final_score = float(final_score)
    else:
        pass

# %%
max_final_score
# Out:
# 100.0

# %%
min_final_score
# Out:
# 0.4570000000000001

# %% [markdown]
# # 最受歡迎的影片為以下

# %%
df[df['final_score'] == max_final_score]
# Out:
#                                       video_url  \
# 43  https://www.youtube.com/watch?v=nmZWfdG0zYA
#
#                                                 title likeCount commentCount  \
# 43  Painting a Forest / Easy Acrylic Painting Tech...    938799        14913
#
#    viewCount  likeCount_score  commentCount_score  viewCount_score  \
# 43  71603085            100.0               100.0            100.0
#
#     final_score
# 43        100.0

# %% [markdown]
# # 最不受歡迎的影片為以下

# %%
df[df['final_score'] == min_final_score]
# Out:
#                                      video_url  \
# 2  https://www.youtube.com/watch?v=RjlajaLYvqk
#
#                                              title likeCount commentCount  \
# 2  Simple Watercolor Painting for Beginners (Easy)      2420          101
#
#   viewCount  likeCount_score  commentCount_score  viewCount_score  final_score
# 2     95156             0.26                0.68             0.13        0.457

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x = df['title']
y = df['final_score']

fig, ax = plt.subplots(figsize=(10, 30))
ax.barh(x, y)
# Out:
# <BarContainer object of 50 artists>

# %%
# 存CSV
filename = 'popularYoutubeVideoAnalyze.csv'
df.to_csv(filename,index=False)
